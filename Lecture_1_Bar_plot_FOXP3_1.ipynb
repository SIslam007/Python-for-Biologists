# %%
import matplotlib.pyplot as plt

# %%
# Data
labels = ['Control', 'Autoimmune disease']
values = [250000, 140000]
#colors = ['skyblue', 'lightcoral']  # Please try different colors!

# %%
# Plot
plt.bar(labels, values, #color=colors)
)

# Add labels
plt.title('FOXP3 Gene Expression')
plt.ylabel('Expression Level')

# Show
plt.show()
